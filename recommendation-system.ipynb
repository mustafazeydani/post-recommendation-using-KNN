# %%
import pandas as pd
import numpy as np

# Load the datasets
post_data = pd.read_csv('datasets/post_data.csv')
view_data = pd.read_csv('datasets/view_data.csv')

dataframe = pd.DataFrame(view_data)

# Generate random probabilities for 1, 2, and 3
probs = np.random.dirichlet(np.ones(3))

# Assign probabilities for the ratings
scores = np.random.choice(
    [1, 2, 3],
    size=len(view_data),
    p=probs
)

# Add the score column to the dataframe
dataframe['score'] = scores

dataframe.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[72], line 5
#       2 import numpy as np
#       4 # Load the datasets
# ----> 5 post_data = pd.read_csv('post_data.csv')
#       6 view_data = pd.read_csv('datasets/view_data.csv')
#       8 dataframe = pd.DataFrame(view_data)
#
# File c:\Users\musta\OneDrive\Desktop\recommendation-system\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\musta\OneDrive\Desktop\recommendation-system\env\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\musta\OneDrive\Desktop\recommendation-system\env\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\musta\OneDrive\Desktop\recommendation-system\env\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\musta\OneDrive\Desktop\recommendation-system\env\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'post_data.csv'

# %%
# Merge the two dataframes
df = pd.merge(dataframe, post_data ,on='post_id')
df.tail()
# Out:
#                         user_id    post_id           time_stamp  score  \
# 71794  5eece14ffc13ae660900018c  615389604  12/31/2019 12:37 AM      1
# 71795  5eece14ffc13ae660900010c  348689108  12/31/2019 12:50 PM      3
# 71796  5eece14ffc13ae6609000190  619052165  12/31/2019 12:51 AM      2
# 71797  5eece14efc13ae6609000067  426384418  12/31/2019 12:51 PM      2
# 71798  5eece14ffc13ae6609000110  165390871  12/31/2019 12:54 AM      3
#
#                                                    title          category
# 71794  5 Brilliant Ways To Teach Your Audience About ...  operating system
# 71795   The Secrets To Finding World Class Tools For ...               GST
# 71796      Double Your Profit With These 5 Tips on CRAFT             Craft
# 71797                         It's All About (The) DANCE             dance
# 71798   3 Ways You Can Reinvent ZOOLOGY Without Looki...           zoology

# %%
# Drop the time_stamp and category columns because they are not needed for now
data = df.drop(['time_stamp', 'category'], axis=1)
data.tail()
# Out:
#                         user_id    post_id  score  \
# 71794  5eece14ffc13ae660900018c  615389604      1
# 71795  5eece14ffc13ae660900010c  348689108      3
# 71796  5eece14ffc13ae6609000190  619052165      2
# 71797  5eece14efc13ae6609000067  426384418      2
# 71798  5eece14ffc13ae6609000110  165390871      3
#
#                                                    title
# 71794  5 Brilliant Ways To Teach Your Audience About ...
# 71795   The Secrets To Finding World Class Tools For ...
# 71796      Double Your Profit With These 5 Tips on CRAFT
# 71797                         It's All About (The) DANCE
# 71798   3 Ways You Can Reinvent ZOOLOGY Without Looki...

# %%
# Create a new dataframe with the total score for each post
# Print the rows length befire and after dropna
posts_with_score = data.dropna(axis = 0, subset = ['title'])
post_totalScore = (posts_with_score.
     groupby(by = ['title'])['score'].
     count().
     reset_index().
     rename(columns = {'score': 'totalScore'})
     [['title', 'totalScore']]
    )
post_totalScore.head()
# Out:
#                        title  totalScore
# 0        10 Funny ART Quotes          15
# 1    10 Funny BANKING Quotes          10
# 2   10 Funny BUSINESS Quotes          13
# 3      10 Funny CRAFT Quotes           9
# 4      10 Funny DANCE Quotes          19

# %%
# Merge the two dataframes
score_with_totalValuableCount = posts_with_score.merge(post_totalScore, left_on = 'title', right_on = 'title', how = 'left')
score_with_totalValuableCount.tail()
# Out:
#                         user_id    post_id  score  \
# 71794  5eece14ffc13ae660900018c  615389604      1
# 71795  5eece14ffc13ae660900010c  348689108      3
# 71796  5eece14ffc13ae6609000190  619052165      2
# 71797  5eece14efc13ae6609000067  426384418      2
# 71798  5eece14ffc13ae6609000110  165390871      3
#
#                                                    title  totalScore
# 71794  5 Brilliant Ways To Teach Your Audience About ...          14
# 71795   The Secrets To Finding World Class Tools For ...           7
# 71796      Double Your Profit With These 5 Tips on CRAFT           8
# 71797                         It's All About (The) DANCE          14
# 71798   3 Ways You Can Reinvent ZOOLOGY Without Looki...          12

# %%
from scipy.sparse import csr_matrix
rating_popular_post = score_with_totalValuableCount.drop_duplicates(['user_id', 'title'])
rating_popular_post_pivot =  rating_popular_post.pivot(index = 'title', columns = 'user_id', values = 'score').fillna(0)
rating_popular_post_matrix = csr_matrix(rating_popular_post_pivot.values)

# Calculate the total number of elements
total_elements = rating_popular_post_matrix.shape[0] * rating_popular_post_matrix.shape[1]

# Get the number of non-zero elements
non_zero_elements = rating_popular_post_matrix.nnz
print(f"Number of non-zero elements: {non_zero_elements}")

# Calculate sparsity
sparsity = (total_elements - non_zero_elements) / total_elements

print(f"Sparsity: {sparsity:.2%}")

rating_popular_post_pivot
# Out:
# Number of non-zero elements: 70614
# Sparsity: 97.65%
# user_id                                             5eece14efc13ae6609000000  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000001  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000002  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000003  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000004  \
# title
#  10 Funny ART Quotes                                                     1.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000005  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000006  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000007  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000008  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14efc13ae6609000009  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    3.0
#
# user_id                                             ...  \
# title                                               ...
#  10 Funny ART Quotes                                ...
#  10 Funny BANKING Quotes                            ...
#  10 Funny BUSINESS Quotes                           ...
#  10 Funny CRAFT Quotes                              ...
#  10 Funny DANCE Quotes                              ...
# ...                                                 ...
# ZOOLOGY: Do You Really Need It? This Will Help ...  ...
# ZOOLOGY: The Samurai Way                            ...
# ZOOLOGY: This Is What Professionals Do              ...
# ZOOLOGY: What A Mistake!                            ...
# ZOOLOGY? It's Easy If You Do It Smart               ...
#
# user_id                                             5eece14ffc13ae66090001ea  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14ffc13ae66090001eb  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14ffc13ae66090001ec  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14ffc13ae66090001ed  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14ffc13ae66090001ee  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    2.0
#
# user_id                                             5eece14ffc13ae66090001ef  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14ffc13ae66090001f0  \
# title
#  10 Funny ART Quotes                                                     3.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14ffc13ae66090001f1  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14ffc13ae66090001f2  \
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# user_id                                             5eece14ffc13ae66090001f3
# title
#  10 Funny ART Quotes                                                     0.0
#  10 Funny BANKING Quotes                                                 0.0
#  10 Funny BUSINESS Quotes                                                0.0
#  10 Funny CRAFT Quotes                                                   0.0
#  10 Funny DANCE Quotes                                                   0.0
# ...                                                                      ...
# ZOOLOGY: Do You Really Need It? This Will Help ...                       0.0
# ZOOLOGY: The Samurai Way                                                 0.0
# ZOOLOGY: This Is What Professionals Do                                   0.0
# ZOOLOGY: What A Mistake!                                                 0.0
# ZOOLOGY? It's Easy If You Do It Smart                                    0.0
#
# [6000 rows x 500 columns]
